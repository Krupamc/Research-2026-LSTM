# %%
from tensorflow import keras
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error
from datetime import datetime
import os
import pandas as pd
import numpy as np

# %%
#Opens a new dataframe with the Clean csv
cleancsv = pd.read_csv('CSV/CLEAN.csv')

# %%
#Convert data into Date time and create date filter
cleancsv['Date'] = pd.to_datetime(cleancsv['Date'])
cleancsv['Date'] = cleancsv['Date'] + pd.to_timedelta(cleancsv["Hr"], unit="h")
cleancsv.drop('Hr', axis=1, inplace=True)

"""
Use this in future if data set needs specific dates
prediction = data.loc{
    (untouched_csv['Date'] > datetime(x, x, x)) &
    (untouched_csv['Date'] < datetime(x, x, x,))
}
"""
# Out:
# "\nUse this in future if data set needs specific dates\nprediction = data.loc{\n    (untouched_csv['Date'] > datetime(x, x, x)) &\n    (untouched_csv['Date'] < datetime(x, x, x,))\n}\n"

# %%
#Prepare colomns into variables
data_main_air_temp = cleancsv['Mainland Air Temp']
data_humidity_per = cleancsv['Humidity (%)']
data_wind_direction = cleancsv['Direction (A)']
data_wind_speed = cleancsv['Wind Speed (A)']
data_gusting = cleancsv['Gusting']
data_pressure = cleancsv['Atmospheric Pressure (IN)']
data_rainfall = cleancsv['Precipitation Rate']
data_bay_temp = cleancsv['Bay Temp']
data_salinity = cleancsv['Salinity']
data_lbi_temp = cleancsv['LBI Air Temp']
data_ocean_temp = cleancsv['Ocean Temp']
data_onshore_flag = cleancsv['Onshore']
data_upwelling_flag = cleancsv['upwelling_flag']

#saves all input data into one Numpy array
dataset = np.column_stack([
    data_main_air_temp.values,
    data_humidity_per.values,
    data_wind_direction.values,
    data_wind_speed.values,
    data_gusting.values,
    data_pressure.values,
    data_rainfall.values,
    data_bay_temp.values,
    data_salinity.values,
    data_lbi_temp.values,
    data_ocean_temp.values,
    #data_onshore_flag.values,
    data_upwelling_flag.values,
])

#Save output data into variables and reshape it to be a 2d array
output_data = data_onshore_flag.values
output_data = np.array(output_data).reshape(-1, 1)

# %%
#Length of training data
training_data_len = int(np.ceil(len(dataset) * 0.95)) #Use 95% of training data

# %%
#Scaler
scaler_x= StandardScaler()
scaler_y= StandardScaler()

scaledx = scaler_x.fit_transform(dataset)
scaledy = scaler_y.fit_transform(output_data)

training_data_x = scaledx[:training_data_len] #95% of all data
training_data_y = scaledy[:training_data_len] #95% of all data

X_train, y_train = [], []

# %%
#Sliding window over last 24 hrs
for i in range(24, training_data_len):
    X_train.append(training_data_x[i-24:i, :])
    y_train.append(training_data_y[i,0])

#Convert lists to arrays
X_train = np.array(X_train)
y_train = np.array(y_train).reshape(-1, 1)

# %%
#Build the model
model = keras.models.Sequential()

# %%
#First Layer input_shape=(X_train.shape[1], 1)
model.add(keras.layers.LSTM(64, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2]) ))
# Out:
# c:\Users\Krupam\miniconda3\envs\lstmenv\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
#Second Layer
model.add(keras.layers.LSTM(64, return_sequences=False))

# %%
#3rd Layer (Dense)
model.add(keras.layers.Dense(128, activation="relu"))

# %%
#4th Layer (Dropout)
model.add(keras.layers.Dropout(0.5))

# %%
#Final Output Layer (Dense)
model.add(keras.layers.Dense(1))

# %%
#Put all the layers together
model.summary()
model.compile(optimizer="adam",
              loss="mae",
              metrics=[keras.metrics.RootMeanSquaredError()])
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_6 (LSTM)                   │ (None, 24, 64)         │        19,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 61,185 (239.00 KB)
#  Trainable params: 61,185 (239.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Train the model

#epochs = # of runs
#batch size = how much data is in each batch
training = model.fit(X_train, y_train, epochs=40, batch_size=32)
# Out:
# Epoch 1/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0327 - root_mean_squared_error: 0.0510
# Epoch 2/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019 - root_mean_squared_error: 0.0042
# Epoch 3/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7610e-04 - root_mean_squared_error: 3.9863e-04
# Epoch 4/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3248e-04 - root_mean_squared_error: 1.5725e-04
# Epoch 5/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5704e-04 - root_mean_squared_error: 1.9859e-04
# Epoch 6/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.8283e-05 - root_mean_squared_error: 1.0938e-04
# Epoch 7/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.4902e-05 - root_mean_squared_error: 7.8354e-05
# Epoch 8/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.3999e-05 - root_mean_squared_error: 1.0813e-04
# Epoch 9/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0816e-04 - root_mean_squared_error: 1.1821e-04
# Epoch 10/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0284e-05 - root_mean_squared_error: 7.9466e-05
# Epoch 11/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.5581e-05 - root_mean_squared_error: 1.2398e-04
# Epoch 12/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3011e-04 - root_mean_squared_error: 1.6436e-04
# Epoch 13/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0358e-04 - root_mean_squared_error: 1.1252e-04
# Epoch 14/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0270e-04 - root_mean_squared_error: 1.0857e-04
# Epoch 15/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.6395e-05 - root_mean_squared_error: 1.0436e-04
# Epoch 16/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0272e-04 - root_mean_squared_error: 1.1036e-04
# Epoch 17/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0022e-04 - root_mean_squared_error: 1.0511e-04
# Epoch 18/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.8636e-05 - root_mean_squared_error: 1.1025e-04
# Epoch 19/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0109e-04 - root_mean_squared_error: 1.1558e-04
# Epoch 20/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.8923e-05 - root_mean_squared_error: 1.0652e-04
# Epoch 21/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.9282e-05 - root_mean_squared_error: 1.0907e-04
# Epoch 22/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.8749e-05 - root_mean_squared_error: 1.0244e-04
# Epoch 23/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.8422e-05 - root_mean_squared_error: 1.0275e-04
# Epoch 24/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7998e-05 - root_mean_squared_error: 1.0675e-04
# Epoch 25/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.7273e-05 - root_mean_squared_error: 1.0882e-04
# Epoch 26/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.8901e-05 - root_mean_squared_error: 1.0593e-04
# Epoch 27/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.7778e-05 - root_mean_squared_error: 1.0139e-04
# Epoch 28/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7530e-05 - root_mean_squared_error: 1.0112e-04
# Epoch 29/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7507e-05 - root_mean_squared_error: 1.0110e-04
# Epoch 30/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7168e-05 - root_mean_squared_error: 1.0075e-04
# Epoch 31/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7258e-05 - root_mean_squared_error: 1.0083e-04
# Epoch 32/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.6936e-05 - root_mean_squared_error: 1.0051e-04
# Epoch 33/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.6981e-05 - root_mean_squared_error: 1.0058e-04
# Epoch 34/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.6816e-05 - root_mean_squared_error: 1.0042e-04
# Epoch 35/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.6855e-05 - root_mean_squared_error: 1.0042e-04
# Epoch 36/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.6608e-05 - root_mean_squared_error: 1.0017e-04
# Epoch 37/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.6721e-05 - root_mean_squared_error: 1.0028e-04
# Epoch 38/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.6478e-05 - root_mean_squared_error: 1.0004e-04
# Epoch 39/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6587e-05 - root_mean_squared_error: 1.0015e-04
# Epoch 40/40
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.6375e-05 - root_mean_squared_error: 9.9934e-05

# %%
test_x = scaledx[training_data_len-24:]
X_test = []

#rebuild window
for i in range(24, len(test_x)):
    X_test.append(test_x[i-24:i, :])

X_test = np.array(X_test)   # (samples_test, 24, n_features)

prediction_scaled = model.predict(X_test)
prediction = scaler_y.inverse_transform(prediction_scaled)  # back to m/s

test_index_start = training_data_len
test_index_end = training_data_len + prediction.shape[0]
y_test_true = cleancsv['Wind Speed (A)'].iloc[test_index_start:test_index_end].values

mae = mean_absolute_error(y_test_true, prediction.ravel())
print("Test MAE (m/s):", mae)   # ≈ 2.1
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Test MAE (m/s): 4.223622176106096
