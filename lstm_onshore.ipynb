# %%
import os
import pandas as pd
import numpy as np
from tensorflow import keras # type: ignore
from sklearn.preprocessing import StandardScaler
from datetime import datetime
from sklearn.metrics import classification_report, confusion_matrix

# %%
#Opens a new dataframe with the Clean csv
cleancsv = pd.read_csv('CSV/CLEAN.csv') 
cleancsv = cleancsv.dropna().reset_index(drop=True)
keras.__version__
# Out:
# '3.13.2'

# %%
#Convert data into Date time and create date filter
cleancsv['Date'] = pd.to_datetime(cleancsv['Date'])
cleancsv['Date'] = cleancsv['Date'] + pd.to_timedelta(cleancsv["Hr"], unit="h")
cleancsv.drop('Hr', axis=1, inplace=True)

"""
Use this in future if data set needs specific dates
prediction = data.loc{
    (untouched_csv['Date'] > datetime(x, x, x)) &
    (untouched_csv['Date'] < datetime(x, x, x,))
}
"""
# Out:
# "\nUse this in future if data set needs specific dates\nprediction = data.loc{\n    (untouched_csv['Date'] > datetime(x, x, x)) &\n    (untouched_csv['Date'] < datetime(x, x, x,))\n}\n"

# %%
#Prepare colomns into variables
data_main_air_temp = cleancsv['Mainland Air Temp']
data_humidity_per = cleancsv['Humidity (%)']
data_wind_direction = cleancsv['Direction (A)']
data_wind_speed = cleancsv['Wind Speed (A)']
data_gusting = cleancsv['Gusting']
data_pressure = cleancsv['Atmospheric Pressure (IN)']
data_rainfall = cleancsv['Precipitation Rate']
data_bay_temp = cleancsv['Bay Temp']
data_salinity = cleancsv['Salinity']
data_lbi_temp = cleancsv['LBI Air Temp']
data_ocean_temp = cleancsv['Ocean Temp']
data_onshore_flag = cleancsv['Onshore']
data_upwelling_flag = cleancsv['upwelling_flag']

#saves all input data into one Numpy array
dataset = np.column_stack([
    data_main_air_temp.values,
    data_humidity_per.values,
    #data_wind_direction.values,
    data_wind_speed.values,
    data_gusting.values,
    data_pressure.values,
    data_rainfall.values,
    data_bay_temp.values,
    data_salinity.values,
    data_lbi_temp.values,
    data_ocean_temp.values,
    data_onshore_flag.values,
    data_upwelling_flag.values,
])

#Save output data into variables and reshape it to be a 2d array
output_data = data_wind_direction.values
#output_data = np.array(output_data).reshape(-1, 1)
output_data = output_data.reshape(-1, 1)

# %%
#Length of training data
training_data_len = int(np.ceil(len(dataset) * 0.90)) #Use 90% of training data

# %%
# 1) Check for NaNs and value distribution
print(cleancsv["Direction (A)"].unique())
print("NaNs:", cleancsv["Direction (A)"].isna().sum())
print("0-degree count:", (cleancsv["Direction (A)"] == 0).sum())
# Out:
# [225.  270.  247.5 292.5 337.5 315.    0.  180.   90.  135.  202.5  22.5
#   67.5  45.  157.5 112.5]
# NaNs: 0
# 0-degree count: 618

# %%
#Scaler
scaler_x= StandardScaler()
scaler_y= StandardScaler()

scaledx = scaler_x.fit_transform(dataset)
scaledy = scaler_y.fit_transform(output_data)

training_data_x = scaledx[:training_data_len] #95% of all data
training_data_y = scaledy[:training_data_len] #95% of all data

X_train, y_train = [], []

# %%
#Sliding window over last 24 hrs
for i in range(24, training_data_len):
    X_train.append(training_data_x[i-24:i, :])
    y_train.append(training_data_y[i,0])

#Convert lists to arrays
X_train = np.array(X_train)
y_train = np.array(y_train).reshape(-1, 1)

# %%
#Build the model
model = keras.models.Sequential()

# %%
#Layer Zero input_shape=(X_train.shape[1], 1)
model.add(keras.layers.Input(shape=(X_train.shape[1], X_train.shape[2])))

# %%
#First Layer input_shape=(X_train.shape[1], 1)
model.add(keras.layers.LSTM(64, return_sequences=True))

# %%
#Second Layer
model.add(keras.layers.LSTM(64, return_sequences=False))

# %%
#3rd Layer (Dense)
model.add(keras.layers.Dense(128, activation="relu"))

# %%
#4th Layer (Dropout)
model.add(keras.layers.Dropout(0.5))

# %%
#Final Output Layer (Dense)
model.add(keras.layers.Dense(1, activation="sigmoid"))

# %%
#Put all the layers together
model.summary()
model.compile(optimizer="adam",
    loss="mae",           
    metrics=[keras.metrics.RootMeanSquaredError])
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 24, 64)         │        19,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 61,185 (239.00 KB)
#  Trainable params: 61,185 (239.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Train the model

#epochs = # of runs
#batch size = how much data is in each batch
training = model.fit(
    X_train,
    y_train, 
    epochs=50, 
    batch_size=32,
    validation_split=0.2,
    shuffle=False,
    )
# Out:
# Epoch 1/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.7134 - root_mean_squared_error: 0.9072 - val_loss: 1.0981 - val_root_mean_squared_error: 1.2621
# Epoch 2/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6561 - root_mean_squared_error: 0.8459 - val_loss: 1.0651 - val_root_mean_squared_error: 1.1952
# Epoch 3/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6164 - root_mean_squared_error: 0.8083 - val_loss: 1.0748 - val_root_mean_squared_error: 1.2293
# Epoch 4/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6037 - root_mean_squared_error: 0.7960 - val_loss: 1.1014 - val_root_mean_squared_error: 1.2708
# Epoch 5/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5912 - root_mean_squared_error: 0.7907 - val_loss: 1.0808 - val_root_mean_squared_error: 1.2427
# Epoch 6/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5871 - root_mean_squared_error: 0.7864 - val_loss: 1.0933 - val_root_mean_squared_error: 1.2691
# Epoch 7/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5787 - root_mean_squared_error: 0.7807 - val_loss: 1.0927 - val_root_mean_squared_error: 1.2630
# Epoch 8/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5700 - root_mean_squared_error: 0.7734 - val_loss: 1.0968 - val_root_mean_squared_error: 1.2633
# Epoch 9/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5642 - root_mean_squared_error: 0.7678 - val_loss: 1.1041 - val_root_mean_squared_error: 1.2595
# Epoch 10/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5640 - root_mean_squared_error: 0.7645 - val_loss: 1.1288 - val_root_mean_squared_error: 1.3115
# Epoch 11/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5521 - root_mean_squared_error: 0.7525 - val_loss: 1.1256 - val_root_mean_squared_error: 1.2968
# Epoch 12/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5584 - root_mean_squared_error: 0.7646 - val_loss: 1.0899 - val_root_mean_squared_error: 1.2389
# Epoch 13/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5614 - root_mean_squared_error: 0.7626 - val_loss: 1.0991 - val_root_mean_squared_error: 1.2428
# Epoch 14/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5555 - root_mean_squared_error: 0.7582 - val_loss: 1.1066 - val_root_mean_squared_error: 1.2483
# Epoch 15/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5535 - root_mean_squared_error: 0.7597 - val_loss: 1.1130 - val_root_mean_squared_error: 1.2550
# Epoch 16/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5426 - root_mean_squared_error: 0.7425 - val_loss: 1.1044 - val_root_mean_squared_error: 1.2402
# Epoch 17/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5413 - root_mean_squared_error: 0.7460 - val_loss: 1.1169 - val_root_mean_squared_error: 1.2695
# Epoch 18/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5480 - root_mean_squared_error: 0.7416 - val_loss: 1.1095 - val_root_mean_squared_error: 1.2599
# Epoch 19/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5450 - root_mean_squared_error: 0.7415 - val_loss: 1.1354 - val_root_mean_squared_error: 1.2852
# Epoch 20/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5335 - root_mean_squared_error: 0.7264 - val_loss: 1.0871 - val_root_mean_squared_error: 1.2175
# Epoch 21/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5336 - root_mean_squared_error: 0.7245 - val_loss: 1.1320 - val_root_mean_squared_error: 1.3082
# Epoch 22/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5256 - root_mean_squared_error: 0.7193 - val_loss: 1.0963 - val_root_mean_squared_error: 1.2638
# Epoch 23/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5266 - root_mean_squared_error: 0.7166 - val_loss: 1.0583 - val_root_mean_squared_error: 1.1967
# Epoch 24/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5302 - root_mean_squared_error: 0.7249 - val_loss: 1.1299 - val_root_mean_squared_error: 1.2827
# Epoch 25/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5344 - root_mean_squared_error: 0.7264 - val_loss: 1.0886 - val_root_mean_squared_error: 1.2245
# Epoch 26/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5251 - root_mean_squared_error: 0.7161 - val_loss: 1.1106 - val_root_mean_squared_error: 1.2547
# Epoch 27/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5222 - root_mean_squared_error: 0.7145 - val_loss: 1.1202 - val_root_mean_squared_error: 1.2789
# Epoch 28/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5157 - root_mean_squared_error: 0.7048 - val_loss: 1.1031 - val_root_mean_squared_error: 1.2404
# Epoch 29/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5117 - root_mean_squared_error: 0.7058 - val_loss: 1.1504 - val_root_mean_squared_error: 1.3203
# Epoch 30/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5186 - root_mean_squared_error: 0.7140 - val_loss: 1.0985 - val_root_mean_squared_error: 1.2410
# Epoch 31/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5138 - root_mean_squared_error: 0.7007 - val_loss: 1.1366 - val_root_mean_squared_error: 1.2983
# Epoch 32/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5143 - root_mean_squared_error: 0.7088 - val_loss: 1.1039 - val_root_mean_squared_error: 1.2420
# Epoch 33/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5114 - root_mean_squared_error: 0.7014 - val_loss: 1.1204 - val_root_mean_squared_error: 1.2900
# Epoch 34/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5114 - root_mean_squared_error: 0.7001 - val_loss: 1.1006 - val_root_mean_squared_error: 1.2402
# Epoch 35/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5097 - root_mean_squared_error: 0.6996 - val_loss: 1.1417 - val_root_mean_squared_error: 1.3219
# Epoch 36/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5112 - root_mean_squared_error: 0.7009 - val_loss: 1.1097 - val_root_mean_squared_error: 1.2692
# Epoch 37/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5085 - root_mean_squared_error: 0.6991 - val_loss: 1.1457 - val_root_mean_squared_error: 1.3154
# Epoch 38/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5130 - root_mean_squared_error: 0.7073 - val_loss: 1.0982 - val_root_mean_squared_error: 1.2630
# Epoch 39/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5052 - root_mean_squared_error: 0.6934 - val_loss: 1.1339 - val_root_mean_squared_error: 1.3018
# Epoch 40/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5083 - root_mean_squared_error: 0.7069 - val_loss: 1.1418 - val_root_mean_squared_error: 1.3200
# Epoch 41/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5032 - root_mean_squared_error: 0.6957 - val_loss: 1.0956 - val_root_mean_squared_error: 1.2422
# Epoch 42/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5090 - root_mean_squared_error: 0.7003 - val_loss: 1.1114 - val_root_mean_squared_error: 1.2855
# Epoch 43/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5042 - root_mean_squared_error: 0.6969 - val_loss: 1.1122 - val_root_mean_squared_error: 1.2761
# Epoch 44/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4978 - root_mean_squared_error: 0.6866 - val_loss: 1.1167 - val_root_mean_squared_error: 1.2755
# Epoch 45/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4964 - root_mean_squared_error: 0.6868 - val_loss: 1.1691 - val_root_mean_squared_error: 1.3551
# Epoch 46/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5044 - root_mean_squared_error: 0.6983 - val_loss: 1.0714 - val_root_mean_squared_error: 1.2151
# Epoch 47/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5034 - root_mean_squared_error: 0.6972 - val_loss: 1.1012 - val_root_mean_squared_error: 1.2683
# Epoch 48/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4979 - root_mean_squared_error: 0.6905 - val_loss: 1.1755 - val_root_mean_squared_error: 1.3674
# Epoch 49/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5020 - root_mean_squared_error: 0.6919 - val_loss: 1.1345 - val_root_mean_squared_error: 1.3005
# Epoch 50/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5021 - root_mean_squared_error: 0.6962 - val_loss: 1.1633 - val_root_mean_squared_error: 1.3463

# %%
test_x = scaledx[training_data_len-24:]
X_test = []

#rebuild window
for i in range(24, len(test_x)):
    X_test.append(test_x[i-24:i, :])

X_test = np.array(X_test)   # (samples_test, 24, n_features)


direction_scaled_pred = model.predict(X_test)        # scaled
direction_pred = scaler_y.inverse_transform(direction_scaled_pred)  # degrees
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
#Round to nearest direction
allowed_dirs = np.array([0, 22.5, 45, 67.5, 90, 112.5, 135, 157.5, 180, 202.5, 225, 247.5, 270, 292.5, 315, 337.5])

# %%
print("direction_scaled_pred shape:", direction_scaled_pred.shape)
print("direction_pred shape:", direction_pred.shape)
print("first 10 direction_pred:", direction_pred[:10].ravel())
# Out:
# direction_scaled_pred shape: (273, 1)
# direction_pred shape: (273, 1)
# first 10 direction_pred: [135.4194  135.4194  135.4194  135.4194  135.4194  135.4194  135.42467
#  206.14749 240.66861 240.72568]

# %%
print("scaledx shape:", scaledx.shape)
print("training_data_len:", training_data_len)
print("test_x shape:", test_x.shape)
print("X_test shape:", X_test.shape)
# Out:
# scaledx shape: (2736, 12)
# training_data_len: 2463
# test_x shape: (297, 12)
# X_test shape: (273, 24, 12)

# %%
#Save preditions to variable
onshore_degrees = [180, 135, 157.5, 90, 67.5, 45, 22.5]

pred_deg = direction_pred.ravel()

# compute index of closest allowed direction for each prediction and save if onshore
idx = np.abs(pred_deg[:, None] - allowed_dirs[None, :]).argmin(axis=1)
onshore_pred_flag = np.isin(pred_deg, onshore_degrees).astype(int)
dir_pred_discrete = allowed_dirs[idx]

# %%
test_start = training_data_len
test_end   = training_data_len + direction_pred.shape[0]

test_df = cleancsv.iloc[test_start:test_end].copy()
#test_df["Dir_pred"] = dir_pred_discrete.ravel()
test_df["Dir_pred"] = pred_deg.ravel()

test_df["Onshore_pred_flag"] = onshore_pred_flag

test_df.to_csv("CSV/predicted_direction_onshore.csv", index=False)

# %%
#BL y_true = cleancsv["Direction (A)"].iloc[test_start:test_end].values
#y_pred = dir_pred_discrete.ravel()

#print(confusion_matrix(y_true, y_pred))
#print(classification_report(y_true, y_pred, digits=3))
