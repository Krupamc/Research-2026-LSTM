# %%
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow import keras
from sklearn.preprocessing import StandardScaler
from datetime import datetime
import os
import pandas as pd
import numpy as np

# %%
#Opens a new dataframe with the Clean csv
cleancsv = pd.read_csv('CSV/CLEAN.csv') 
cleancsv = cleancsv.dropna().reset_index(drop=True)

# %%
#Convert data into Date time and create date filter
cleancsv['Date'] = pd.to_datetime(cleancsv['Date'])
cleancsv['Date'] = cleancsv['Date'] + pd.to_timedelta(cleancsv["Hr"], unit="h")
cleancsv.drop('Hr', axis=1, inplace=True)

"""
Use this in future if data set needs specific dates
prediction = data.loc{
    (untouched_csv['Date'] > datetime(x, x, x)) &
    (untouched_csv['Date'] < datetime(x, x, x,))
}
"""
# Out:
# "\nUse this in future if data set needs specific dates\nprediction = data.loc{\n    (untouched_csv['Date'] > datetime(x, x, x)) &\n    (untouched_csv['Date'] < datetime(x, x, x,))\n}\n"

# %%
#Prepare colomns into variables
data_main_air_temp = cleancsv['Mainland Air Temp']
data_humidity_per = cleancsv['Humidity (%)']
data_wind_direction = cleancsv['Direction (A)']
data_wind_speed = cleancsv['Wind Speed (A)']
data_gusting = cleancsv['Gusting']
data_pressure = cleancsv['Atmospheric Pressure (IN)']
data_rainfall = cleancsv['Precipitation Rate']
data_bay_temp = cleancsv['Bay Temp']
data_salinity = cleancsv['Salinity']
data_lbi_temp = cleancsv['LBI Air Temp']
data_ocean_temp = cleancsv['Ocean Temp']
data_onshore_flag = cleancsv['Onshore']
data_upwelling_flag = cleancsv['upwelling_flag']

#saves all input data into one Numpy array
dataset = np.column_stack([
    data_main_air_temp.values,
    data_humidity_per.values,
    #data_wind_direction.values,
    data_wind_speed.values,
    data_gusting.values,
    data_pressure.values,
    data_rainfall.values,
    data_bay_temp.values,
    data_salinity.values,
    data_lbi_temp.values,
    data_ocean_temp.values,
    data_onshore_flag.values,
    data_upwelling_flag.values,
])

#Save output data into variables and reshape it to be a 2d array
output_data = data_wind_direction.values
#output_data = np.array(output_data).reshape(-1, 1)
output_data = output_data.reshape(-1, 1)

# %%
#Length of training data
training_data_len = int(np.ceil(len(dataset) * 0.90)) #Use 90% of training data

# %%
# 1) Check for NaNs and value distribution
print(cleancsv["Direction (A)"].unique())
print("NaNs:", cleancsv["Direction (A)"].isna().sum())
print("0-degree count:", (cleancsv["Direction (A)"] == 0).sum())
# Out:
# [225.  270.  247.5 292.5 337.5 315.    0.  180.   90.  135.  202.5  22.5
#   67.5  45.  157.5 112.5]
# NaNs: 0
# 0-degree count: 618

# %%
#Scaler
scaler_x= StandardScaler()
scaler_y= StandardScaler()

scaledx = scaler_x.fit_transform(dataset)
scaledy = scaler_y.fit_transform(output_data)

training_data_x = scaledx[:training_data_len] #95% of all data
training_data_y = scaledy[:training_data_len] #95% of all data

X_train, y_train = [], []

# %%
#Sliding window over last 24 hrs
for i in range(24, training_data_len):
    X_train.append(training_data_x[i-24:i, :])
    y_train.append(training_data_y[i,0])

#Convert lists to arrays
X_train = np.array(X_train)
y_train = np.array(y_train).reshape(-1, 1)

# %%
#Build the model
model = keras.models.Sequential()

# %%
#Layer Zero input_shape=(X_train.shape[1], 1)
model.add(keras.layers.Input(shape=(X_train.shape[1], X_train.shape[2])))

# %%
#First Layer input_shape=(X_train.shape[1], 1)
model.add(keras.layers.LSTM(64, return_sequences=True))

# %%
#Second Layer
model.add(keras.layers.LSTM(64, return_sequences=False))

# %%
#3rd Layer (Dense)
model.add(keras.layers.Dense(128, activation="relu"))

# %%
#4th Layer (Dropout)
model.add(keras.layers.Dropout(0.5))

# %%
#Final Output Layer (Dense)
model.add(keras.layers.Dense(1, activation="sigmoid"))

# %%
#Put all the layers together
model.summary()
model.compile(optimizer="adam",
    loss="mae",           
    metrics=[keras.metrics.RootMeanSquaredError])
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 24, 64)         │        19,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 61,185 (239.00 KB)
#  Trainable params: 61,185 (239.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Train the model

#epochs = # of runs
#batch size = how much data is in each batch
training = model.fit(
    X_train,
    y_train, 
    epochs=50, 
    batch_size=32,
    validation_split=0.2,
    shuffle=False,
    )
# Out:
# Epoch 1/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.7069 - root_mean_squared_error: 0.9050 - val_loss: 1.0878 - val_root_mean_squared_error: 1.2434
# Epoch 2/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6538 - root_mean_squared_error: 0.8425 - val_loss: 1.0582 - val_root_mean_squared_error: 1.1862
# Epoch 3/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6173 - root_mean_squared_error: 0.8136 - val_loss: 1.0862 - val_root_mean_squared_error: 1.2246
# Epoch 4/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6095 - root_mean_squared_error: 0.8037 - val_loss: 1.1136 - val_root_mean_squared_error: 1.2872
# Epoch 5/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5906 - root_mean_squared_error: 0.7964 - val_loss: 1.0714 - val_root_mean_squared_error: 1.2271
# Epoch 6/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5864 - root_mean_squared_error: 0.7832 - val_loss: 1.0897 - val_root_mean_squared_error: 1.2520
# Epoch 7/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5750 - root_mean_squared_error: 0.7800 - val_loss: 1.1204 - val_root_mean_squared_error: 1.2939
# Epoch 8/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5677 - root_mean_squared_error: 0.7694 - val_loss: 1.1440 - val_root_mean_squared_error: 1.3203
# Epoch 9/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5708 - root_mean_squared_error: 0.7749 - val_loss: 1.1100 - val_root_mean_squared_error: 1.2874
# Epoch 10/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5657 - root_mean_squared_error: 0.7653 - val_loss: 1.1182 - val_root_mean_squared_error: 1.2823
# Epoch 11/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5550 - root_mean_squared_error: 0.7565 - val_loss: 1.1240 - val_root_mean_squared_error: 1.2935
# Epoch 12/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5534 - root_mean_squared_error: 0.7528 - val_loss: 1.1569 - val_root_mean_squared_error: 1.3375
# Epoch 13/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5530 - root_mean_squared_error: 0.7512 - val_loss: 1.1254 - val_root_mean_squared_error: 1.3036
# Epoch 14/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5485 - root_mean_squared_error: 0.7465 - val_loss: 1.1128 - val_root_mean_squared_error: 1.2815
# Epoch 15/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5442 - root_mean_squared_error: 0.7427 - val_loss: 1.1216 - val_root_mean_squared_error: 1.2876
# Epoch 16/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5457 - root_mean_squared_error: 0.7471 - val_loss: 1.1111 - val_root_mean_squared_error: 1.2937
# Epoch 17/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5389 - root_mean_squared_error: 0.7348 - val_loss: 1.1381 - val_root_mean_squared_error: 1.3315
# Epoch 18/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5362 - root_mean_squared_error: 0.7315 - val_loss: 1.1813 - val_root_mean_squared_error: 1.3844
# Epoch 19/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5430 - root_mean_squared_error: 0.7406 - val_loss: 1.1058 - val_root_mean_squared_error: 1.2802
# Epoch 20/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5406 - root_mean_squared_error: 0.7359 - val_loss: 1.0991 - val_root_mean_squared_error: 1.2736
# Epoch 21/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5386 - root_mean_squared_error: 0.7322 - val_loss: 1.1280 - val_root_mean_squared_error: 1.3173
# Epoch 22/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5353 - root_mean_squared_error: 0.7259 - val_loss: 1.1696 - val_root_mean_squared_error: 1.3567
# Epoch 23/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5268 - root_mean_squared_error: 0.7134 - val_loss: 1.1894 - val_root_mean_squared_error: 1.3940
# Epoch 24/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5237 - root_mean_squared_error: 0.7207 - val_loss: 1.1222 - val_root_mean_squared_error: 1.3064
# Epoch 25/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5248 - root_mean_squared_error: 0.7153 - val_loss: 1.1443 - val_root_mean_squared_error: 1.3246
# Epoch 26/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5268 - root_mean_squared_error: 0.7146 - val_loss: 1.1715 - val_root_mean_squared_error: 1.3688
# Epoch 27/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5282 - root_mean_squared_error: 0.7243 - val_loss: 1.1302 - val_root_mean_squared_error: 1.2987
# Epoch 28/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5170 - root_mean_squared_error: 0.7037 - val_loss: 1.1378 - val_root_mean_squared_error: 1.3125
# Epoch 29/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5112 - root_mean_squared_error: 0.7009 - val_loss: 1.1875 - val_root_mean_squared_error: 1.3836
# Epoch 30/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5179 - root_mean_squared_error: 0.7103 - val_loss: 1.1471 - val_root_mean_squared_error: 1.3203
# Epoch 31/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5174 - root_mean_squared_error: 0.7068 - val_loss: 1.1775 - val_root_mean_squared_error: 1.3702
# Epoch 32/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5128 - root_mean_squared_error: 0.6991 - val_loss: 1.1528 - val_root_mean_squared_error: 1.3316
# Epoch 33/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5116 - root_mean_squared_error: 0.7052 - val_loss: 1.1653 - val_root_mean_squared_error: 1.3433
# Epoch 34/50
# 13/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4066 - root_mean_squared_error: 0.5889

# %%
test_x = scaledx[training_data_len-24:]
X_test = []

#rebuild window
for i in range(24, len(test_x)):
    X_test.append(test_x[i-24:i, :])

X_test = np.array(X_test)   # (samples_test, 24, n_features)


direction_scaled_pred = model.predict(X_test)        # scaled
direction_pred = scaler_y.inverse_transform(direction_scaled_pred)  # degrees
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
#Round to nearest direction
allowed_dirs = np.array([0, 22.5, 45, 67.5, 90, 112.5, 135, 157.5, 180, 202.5, 225, 247.5, 270, 292.5, 315, 337.5])

# %%
print("direction_scaled_pred shape:", direction_scaled_pred.shape)
print("direction_pred shape:", direction_pred.shape)
print("first 10 direction_pred:", direction_pred[:10].ravel())
# Out:
# direction_scaled_pred shape: (273, 1)
# direction_pred shape: (273, 1)
# first 10 direction_pred: [135.4194  135.4194  135.4194  135.4194  135.4194  135.4194  135.4196
#  189.00279 240.66382 240.73251]

# %%
print("scaledx shape:", scaledx.shape)
print("training_data_len:", training_data_len)
print("test_x shape:", test_x.shape)
print("X_test shape:", X_test.shape)
# Out:
# scaledx shape: (2736, 12)
# training_data_len: 2463
# test_x shape: (297, 12)
# X_test shape: (273, 24, 12)

# %%
onshore_degrees = [180, 135, 157.5, 90, 67.5, 45, 22.5]


pred_deg = direction_pred.ravel()
# compute index of closest allowed direction for each prediction and save if onshore
idx = np.abs(pred_deg[:, None] - allowed_dirs[None, :]).argmin(axis=1)
onshore_pred_flag = np.isin(pred_deg, onshore_degrees).astype(int)
dir_pred_discrete = allowed_dirs[idx]

# %%
test_start = training_data_len
test_end   = training_data_len + direction_pred.shape[0]

test_df = cleancsv.iloc[test_start:test_end].copy()
test_df["Dir_pred"] = dir_pred_discrete.ravel()

test_df["Onshore_pred_flag"] = onshore_pred_flag

test_df.to_csv("CSV/predicted_direction_onshore.csv", index=False)

# %%
#BL y_true = cleancsv["Direction (A)"].iloc[test_start:test_end].values
#y_pred = dir_pred_discrete.ravel()

#print(confusion_matrix(y_true, y_pred))
#print(classification_report(y_true, y_pred, digits=3))
