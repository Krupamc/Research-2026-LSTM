# %%
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow import keras
from sklearn.preprocessing import StandardScaler
from datetime import datetime
import os
import pandas as pd
import numpy as np

# %%
#Opens a new dataframe with the Clean csv
cleancsv = pd.read_csv('CSV/CLEAN.csv') 
cleancsv = cleancsv.dropna().reset_index(drop=True)

# %%
#Convert data into Date time and create date filter
cleancsv['Date'] = pd.to_datetime(cleancsv['Date'])
cleancsv['Date'] = cleancsv['Date'] + pd.to_timedelta(cleancsv["Hr"], unit="h")
cleancsv.drop('Hr', axis=1, inplace=True)

"""
Use this in future if data set needs specific dates
prediction = data.loc{
    (untouched_csv['Date'] > datetime(x, x, x)) &
    (untouched_csv['Date'] < datetime(x, x, x,))
}
"""
# Out:
# "\nUse this in future if data set needs specific dates\nprediction = data.loc{\n    (untouched_csv['Date'] > datetime(x, x, x)) &\n    (untouched_csv['Date'] < datetime(x, x, x,))\n}\n"

# %%
#Prepare colomns into variables
data_main_air_temp = cleancsv['Mainland Air Temp']
data_humidity_per = cleancsv['Humidity (%)']
data_wind_direction = cleancsv['Direction (A)']
data_wind_speed = cleancsv['Wind Speed (A)']
data_gusting = cleancsv['Gusting']
data_pressure = cleancsv['Atmospheric Pressure (IN)']
data_rainfall = cleancsv['Precipitation Rate']
data_bay_temp = cleancsv['Bay Temp']
data_salinity = cleancsv['Salinity']
data_lbi_temp = cleancsv['LBI Air Temp']
data_ocean_temp = cleancsv['Ocean Temp']
data_onshore_flag = cleancsv['Onshore']
data_upwelling_flag = cleancsv['upwelling_flag']

#saves all input data into one Numpy array
dataset = np.column_stack([
    data_main_air_temp.values,
    data_humidity_per.values,
    #data_wind_direction.values,
    data_wind_speed.values,
    data_gusting.values,
    data_pressure.values,
    data_rainfall.values,
    data_bay_temp.values,
    data_salinity.values,
    data_lbi_temp.values,
    data_ocean_temp.values,
    data_onshore_flag.values,
    data_upwelling_flag.values,
])

#Save output data into variables and reshape it to be a 2d array
output_data = data_wind_direction.values
#output_data = np.array(output_data).reshape(-1, 1)
output_data = output_data.reshape(-1, 1)

# %%
#Length of training data
training_data_len = int(np.ceil(len(dataset) * 0.90)) #Use 90% of training data

# %%
# 1) Check for NaNs and value distribution
print(cleancsv["Direction (A)"].unique())
print("NaNs:", cleancsv["Direction (A)"].isna().sum())
print("0-degree count:", (cleancsv["Direction (A)"] == 0).sum())
# Out:
# [225.  270.  247.5 292.5 337.5 315.    0.  180.   90.  135.  202.5  22.5
#   67.5  45.  157.5 112.5]
# NaNs: 0
# 0-degree count: 618

# %%
#Scaler
scaler_x= StandardScaler()
scaler_y= StandardScaler()

scaledx = scaler_x.fit_transform(dataset)
scaledy = scaler_y.fit_transform(output_data)

training_data_x = scaledx[:training_data_len] #95% of all data
training_data_y = scaledy[:training_data_len] #95% of all data

X_train, y_train = [], []

# %%
#Sliding window over last 24 hrs
for i in range(24, training_data_len):
    X_train.append(training_data_x[i-24:i, :])
    y_train.append(training_data_y[i,0])

#Convert lists to arrays
X_train = np.array(X_train)
y_train = np.array(y_train).reshape(-1, 1)

# %%
#Build the model
model = keras.models.Sequential()

# %%
#Layer Zero input_shape=(X_train.shape[1], 1)
model.add(keras.layers.Input(shape=(X_train.shape[1], X_train.shape[2])))

# %%
#First Layer input_shape=(X_train.shape[1], 1)
model.add(keras.layers.LSTM(64, return_sequences=True))

# %%
#Second Layer
model.add(keras.layers.LSTM(64, return_sequences=False))

# %%
#3rd Layer (Dense)
model.add(keras.layers.Dense(128, activation="relu"))

# %%
#4th Layer (Dropout)
model.add(keras.layers.Dropout(0.5))

# %%
#Final Output Layer (Dense)
model.add(keras.layers.Dense(1, activation="sigmoid"))

# %%
#Put all the layers together
model.summary()
model.compile(optimizer="adam",
    loss="mae",           
    metrics=[keras.metrics.RootMeanSquaredError])
# Out:
# Model: "sequential_17"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_34 (LSTM)                  │ (None, 24, 64)         │        19,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_35 (LSTM)                  │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_34 (Dense)                │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_35 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 61,185 (239.00 KB)
#  Trainable params: 61,185 (239.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Train the model

#epochs = # of runs
#batch size = how much data is in each batch
training = model.fit(
    X_train,
    y_train, 
    epochs=50, 
    batch_size=32,
    validation_split=0.2,
    shuffle=False,
    )
# Out:
# Epoch 1/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.7079 - root_mean_squared_error: 0.9068 - val_loss: 1.1245 - val_root_mean_squared_error: 1.2948
# Epoch 2/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6554 - root_mean_squared_error: 0.8445 - val_loss: 1.0640 - val_root_mean_squared_error: 1.2111
# Epoch 3/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6160 - root_mean_squared_error: 0.8166 - val_loss: 1.0857 - val_root_mean_squared_error: 1.2481
# Epoch 4/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6040 - root_mean_squared_error: 0.8001 - val_loss: 1.1296 - val_root_mean_squared_error: 1.3081
# Epoch 5/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5933 - root_mean_squared_error: 0.7966 - val_loss: 1.0957 - val_root_mean_squared_error: 1.2570
# Epoch 6/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5842 - root_mean_squared_error: 0.7854 - val_loss: 1.1262 - val_root_mean_squared_error: 1.3065
# Epoch 7/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5788 - root_mean_squared_error: 0.7866 - val_loss: 1.0973 - val_root_mean_squared_error: 1.2686
# Epoch 8/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5701 - root_mean_squared_error: 0.7778 - val_loss: 1.1233 - val_root_mean_squared_error: 1.2982
# Epoch 9/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5650 - root_mean_squared_error: 0.7719 - val_loss: 1.1466 - val_root_mean_squared_error: 1.3457
# Epoch 10/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5644 - root_mean_squared_error: 0.7708 - val_loss: 1.1259 - val_root_mean_squared_error: 1.2937
# Epoch 11/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5597 - root_mean_squared_error: 0.7613 - val_loss: 1.1587 - val_root_mean_squared_error: 1.3590
# Epoch 12/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5561 - root_mean_squared_error: 0.7573 - val_loss: 1.1909 - val_root_mean_squared_error: 1.3928
# Epoch 13/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5589 - root_mean_squared_error: 0.7647 - val_loss: 1.1146 - val_root_mean_squared_error: 1.2851
# Epoch 14/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5568 - root_mean_squared_error: 0.7648 - val_loss: 1.1284 - val_root_mean_squared_error: 1.2933
# Epoch 15/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5477 - root_mean_squared_error: 0.7485 - val_loss: 1.1414 - val_root_mean_squared_error: 1.3144
# Epoch 16/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5475 - root_mean_squared_error: 0.7448 - val_loss: 1.2290 - val_root_mean_squared_error: 1.4392
# Epoch 17/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5476 - root_mean_squared_error: 0.7512 - val_loss: 1.1153 - val_root_mean_squared_error: 1.2725
# Epoch 18/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5449 - root_mean_squared_error: 0.7413 - val_loss: 1.1444 - val_root_mean_squared_error: 1.3391
# Epoch 19/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5416 - root_mean_squared_error: 0.7394 - val_loss: 1.1911 - val_root_mean_squared_error: 1.3807
# Epoch 20/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5381 - root_mean_squared_error: 0.7396 - val_loss: 1.1332 - val_root_mean_squared_error: 1.3180
# Epoch 21/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5370 - root_mean_squared_error: 0.7361 - val_loss: 1.1658 - val_root_mean_squared_error: 1.3546
# Epoch 22/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5290 - root_mean_squared_error: 0.7223 - val_loss: 1.1405 - val_root_mean_squared_error: 1.3331
# Epoch 23/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5246 - root_mean_squared_error: 0.7166 - val_loss: 1.2190 - val_root_mean_squared_error: 1.4260
# Epoch 24/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5296 - root_mean_squared_error: 0.7304 - val_loss: 1.1219 - val_root_mean_squared_error: 1.3075
# Epoch 25/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5220 - root_mean_squared_error: 0.7136 - val_loss: 1.1553 - val_root_mean_squared_error: 1.3349
# Epoch 26/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5205 - root_mean_squared_error: 0.7092 - val_loss: 1.2354 - val_root_mean_squared_error: 1.4612
# Epoch 27/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5235 - root_mean_squared_error: 0.7164 - val_loss: 1.1097 - val_root_mean_squared_error: 1.2805
# Epoch 28/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5226 - root_mean_squared_error: 0.7140 - val_loss: 1.1335 - val_root_mean_squared_error: 1.3135
# Epoch 29/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5264 - root_mean_squared_error: 0.7131 - val_loss: 1.2036 - val_root_mean_squared_error: 1.4094
# Epoch 30/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5197 - root_mean_squared_error: 0.7090 - val_loss: 1.1845 - val_root_mean_squared_error: 1.3922
# Epoch 31/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5136 - root_mean_squared_error: 0.6939 - val_loss: 1.2321 - val_root_mean_squared_error: 1.4390
# Epoch 32/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5136 - root_mean_squared_error: 0.7030 - val_loss: 1.1727 - val_root_mean_squared_error: 1.3786
# Epoch 33/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5027 - root_mean_squared_error: 0.6884 - val_loss: 1.2164 - val_root_mean_squared_error: 1.4301
# Epoch 34/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5043 - root_mean_squared_error: 0.6881 - val_loss: 1.2155 - val_root_mean_squared_error: 1.4362
# Epoch 35/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5073 - root_mean_squared_error: 0.6944 - val_loss: 1.2426 - val_root_mean_squared_error: 1.4723
# Epoch 36/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5111 - root_mean_squared_error: 0.7026 - val_loss: 1.2769 - val_root_mean_squared_error: 1.5026
# Epoch 37/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5061 - root_mean_squared_error: 0.6928 - val_loss: 1.1609 - val_root_mean_squared_error: 1.3554
# Epoch 38/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4986 - root_mean_squared_error: 0.6821 - val_loss: 1.2295 - val_root_mean_squared_error: 1.4452
# Epoch 39/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5024 - root_mean_squared_error: 0.6889 - val_loss: 1.1764 - val_root_mean_squared_error: 1.3731
# Epoch 40/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5070 - root_mean_squared_error: 0.6944 - val_loss: 1.2664 - val_root_mean_squared_error: 1.4918
# Epoch 41/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5117 - root_mean_squared_error: 0.7082 - val_loss: 1.1355 - val_root_mean_squared_error: 1.3219
# Epoch 42/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5060 - root_mean_squared_error: 0.7001 - val_loss: 1.1846 - val_root_mean_squared_error: 1.3853
# Epoch 43/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5098 - root_mean_squared_error: 0.7051 - val_loss: 1.2050 - val_root_mean_squared_error: 1.4232
# Epoch 44/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5075 - root_mean_squared_error: 0.6982 - val_loss: 1.1350 - val_root_mean_squared_error: 1.3239
# Epoch 45/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5057 - root_mean_squared_error: 0.6921 - val_loss: 1.2561 - val_root_mean_squared_error: 1.4731
# Epoch 46/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5045 - root_mean_squared_error: 0.6953 - val_loss: 1.2060 - val_root_mean_squared_error: 1.4042
# Epoch 47/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5122 - root_mean_squared_error: 0.7005 - val_loss: 1.1528 - val_root_mean_squared_error: 1.3456
# Epoch 48/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5094 - root_mean_squared_error: 0.6982 - val_loss: 1.2573 - val_root_mean_squared_error: 1.4758
# Epoch 49/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4993 - root_mean_squared_error: 0.6854 - val_loss: 1.2983 - val_root_mean_squared_error: 1.5345
# Epoch 50/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4950 - root_mean_squared_error: 0.6826 - val_loss: 1.2232 - val_root_mean_squared_error: 1.4369

# %%
test_x = scaledx[training_data_len-24:]
X_test = []

#rebuild window
for i in range(24, len(test_x)):
    X_test.append(test_x[i-24:i, :])

X_test = np.array(X_test)   # (samples_test, 24, n_features)


direction_scaled_pred = model.predict(X_test)        # scaled
direction_pred = scaler_y.inverse_transform(direction_scaled_pred)  # degrees
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
#Round to nearest direction
allowed_dirs = np.array([0, 22.5, 45, 67.5, 90, 112.5, 135, 157.5, 180, 202.5, 225, 247.5, 270, 292.5, 315, 337.5])

# %%
print("direction_scaled_pred shape:", direction_scaled_pred.shape)
print("direction_pred shape:", direction_pred.shape)
print("first 10 direction_pred:", direction_pred[:10].ravel())
# Out:
# direction_scaled_pred shape: (273, 1)
# direction_pred shape: (273, 1)
# first 10 direction_pred: [135.4194  135.4194  135.4194  135.4194  135.4194  135.41942 135.4836
#  223.3337  239.52205 240.49864]

# %%
print("scaledx shape:", scaledx.shape)
print("training_data_len:", training_data_len)
print("test_x shape:", test_x.shape)
print("X_test shape:", X_test.shape)
# Out:
# scaledx shape: (2736, 12)
# training_data_len: 2463
# test_x shape: (297, 12)
# X_test shape: (273, 24, 12)

# %%
onshore_degrees = [180, 135, 157.5, 90, 67.5, 45, 22.5]


pred_deg = direction_pred.ravel()
# compute index of closest allowed direction for each prediction and save if onshore
idx = np.abs(pred_deg[:, None] - allowed_dirs[None, :]).argmin(axis=1)
onshore_pred_flag = np.isin(pred_deg, onshore_degrees).astype(int)
dir_pred_discrete = allowed_dirs[idx]

# %%
test_start = training_data_len
test_end   = training_data_len + direction_pred.shape[0]

test_df = cleancsv.iloc[test_start:test_end].copy()
test_df["Dir_pred"] = dir_pred_discrete.ravel()

test_df["Onshore_pred_flag"] = onshore_pred_flag

test_df.to_csv("CSV/predicted_direction_onshore.csv", index=False)

# %%
#BL y_true = cleancsv["Direction (A)"].iloc[test_start:test_end].values
#y_pred = dir_pred_discrete.ravel()

#print(confusion_matrix(y_true, y_pred))
#print(classification_report(y_true, y_pred, digits=3))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[479], line 4
#       1 y_true = cleancsv["Direction (A)"].iloc[test_start:test_end].values
#       2 y_pred = dir_pred_discrete.ravel()
# ----> 4 print(confusion_matrix(y_true, y_pred))
#       5 print(classification_report(y_true, y_pred, digits=3))
#
# File c:\Users\Krupam\miniconda3\envs\lstmenv\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\Users\Krupam\miniconda3\envs\lstmenv\Lib\site-packages\sklearn\metrics\_classification.py:467, in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     384 """Compute confusion matrix to evaluate the accuracy of a classification.
#     385
#     386 By definition a confusion matrix :math:`C` is such that :math:`C_{i, j}`
#    (...)    464 (0, 2, 1, 1)
#     465 """
#     466 y_true, y_pred = attach_unique(y_true, y_pred)
# --> 467 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     468 if y_type not in ("binary", "multiclass"):
#     469     raise ValueError("%s is not supported" % y_type)
#
# File c:\Users\Krupam\miniconda3\envs\lstmenv\Lib\site-packages\sklearn\metrics\_classification.py:117, in _check_targets(y_true, y_pred)
#     115 # No metrics support "multiclass-multioutput" format
#     116 if y_type not in ["binary", "multiclass", "multilabel-indicator"]:
# --> 117     raise ValueError("{0} is not supported".format(y_type))
#     119 if y_type in ["binary", "multiclass"]:
#     120     xp, _ = get_namespace(y_true, y_pred)
#
# ValueError: continuous is not supported
