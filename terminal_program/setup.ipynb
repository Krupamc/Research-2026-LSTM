# %%
#Announce to the user the point of this program

print("------Hello This program is download the dependancies required and create A virtual enviroment for the program-----")
print("-----(A virtual enviroment = Dependancies are not downloaded to the main computer but instead a seperate python installation seperated from everything)-----")
print("-----Pandas, Numpy, Tensorflow, and Scikit-Learn will be required and will be downloaded after----")
# Out:
# ------Hello This program is download the dependancies required and create A virtual enviroment for the program-----
# -----(A virtual enviroment = Dependancies are not downloaded to the main computer but instead a seperate python installation seperated from everything)-----
# -----Pandas, Numpy, Tensorflow, and Scikit-Learn will be required and will be downloaded after----

# %%
#ask if env or no
ask = input("-----If you like for everything to run in a virtual enviroment enter 'y' for yes and 'n' for no ").strip().lower()
print("-----(This is the way any question must be answered unless specified :D)-----")

if (ask == 'n'):
    print("-----No virual enviroment was created-----")
    #install all programs
    ask = input("Do you have Pandas?").strip().lower()
    if (ask == 'n'):
        print("-----Installing Pandas-----")
        # %pip install pandas
    
    ask = input("Do you have Numpy?").strip().lower()
    if (ask == 'n'):
        print("-----Installing Numpy-----")
        # %pip install numpy
    
    ask = input("Do you have Tensorflow?").strip().lower()
    if (ask == 'n'):
        print("-----Installing Tensorflow-----")
        # %pip install tensorflow

    ask = input("Do you have Scikit-Learn?").strip().lower()
    if (ask == 'n'):
        print("-----Installing Scikit-Learn-----")
        # %pip install Scikit-Learn
        print("Installed Pandas, Numpy, Tensorflow, and Scikit-Learn")

elif (ask == 'y'):
    ask = input("What do you want to call this virtual enviroment?")
    # !python -m venv "{ask}"
# Out:
# -----(This is the way any question must be answered unless specified :D)-----
